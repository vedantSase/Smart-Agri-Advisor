# %%
import numpy as np
import pandas as pd
import warnings
import math
warnings.filterwarnings("ignore", message="Optimization failed to converge")

# %%
df=pd.read_csv(r'crop_production1.csv')

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
# Filter the data for Rice in Rabi season from Chittoor
filtered_data = df[
    (df['Crop'] == 'Rice') |  # Crop is Rice
    (df['Season'] == 'Rabi') |  # Season is Rabi
    (df['District_Name'] == 'CHITTOOR')  # District is Chittoor
]

# Extract the data for the last 10 years and sort by year
filtered_data_last_10_years = filtered_data.sort_values(by='Crop_Year', ascending=False).head(10)

# Create a dictionary with years as keys and a tuple (area, production) as values
area_production_by_year = dict(zip(filtered_data_last_10_years['Crop_Year'], zip(filtered_data_last_10_years['Area'], filtered_data_last_10_years['Production'])))

# Display the result
print("Area and production data by year (last 10 years):")
print(area_production_by_year)
# Out:
# Area and production data by year (last 10 years):
# {2015: (74000.0, 49000.0)}

# %%
df.head(2)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0

# %%
# Filter the data for Kharif season in Anantapur
filtered_data_kharif_anantapur = df[
    (df['Season'] == 'Kharif') | # Season is Kharif
    (df['District_Name'] == 'ANANTAPUR')|  # District is Anantapur
    (df['Crop']=='Coconut')
]

# Sort by production to find the best-performing crops (if production is the criterion)
sorted_data_by_production = filtered_data_kharif_anantapur.sort_values(by='Production', ascending=False)

# Display the crops with the highest production
best_crops_kharif_anantapur = sorted_data_by_production[['Crop', 'Area', 'Production']]
print("Top-performing crops for Kharif season in Anantapur:")
best_crops_kharif_anantapur
# Out:
# Top-performing crops for Kharif season in Anantapur:
#                  Crop    Area  Production
# 790          Coconut    895.0   7165320.0
# 665          Coconut    786.0   7141464.0
# 528          Coconut    837.0   6413350.0
# 609          Coconut    790.0   6404076.0
# 989          Coconut    687.0   5756000.0
# ..                ...     ...         ...
# 424          Cucumber    18.0         0.0
# 428      other fibres   132.0         0.0
# 430  Other Vegetables  1767.0         0.0
# 397          Soyabean    51.0         0.0
# 486  Other Vegetables  1783.0         0.0
#
# [788 rows x 3 columns]

# %%
df = df.groupby(['State_Name', 'Season', 'Crop'])[['Area', 'Production']].sum().reset_index()
df
# Out:
#                        State_Name       Season                 Crop  \
# 0     Andaman and Nicobar Islands  Autumn                      Rice
# 1     Andaman and Nicobar Islands  Autumn                 Sugarcane
# 2     Andaman and Nicobar Islands  Kharif                  Arecanut
# 3     Andaman and Nicobar Islands  Kharif       Other Kharif pulses
# 4     Andaman and Nicobar Islands  Kharif                      Rice
# ...                           ...          ...                  ...
# 1960                  West Bengal  Whole Year               Tobacco
# 1961                  West Bengal  Whole Year              Turmeric
# 1962                  West Bengal  Winter                    Potato
# 1963                  West Bengal  Winter                      Rice
# 1964                  West Bengal  Winter                   Sesamum
#
#              Area    Production
# 0         8390.00  2.391600e+04
# 1          154.23  1.332950e+03
# 2         8708.00  1.450000e+04
# ...

# %%
df['Area'] = df['Area'].apply(math.ceil)
df['Production'] = df['Production'].apply(math.ceil)
df
# Out:
#                        State_Name       Season                 Crop      Area  \
# 0     Andaman and Nicobar Islands  Autumn                      Rice      8390
# 1     Andaman and Nicobar Islands  Autumn                 Sugarcane       155
# 2     Andaman and Nicobar Islands  Kharif                  Arecanut      8708
# 3     Andaman and Nicobar Islands  Kharif       Other Kharif pulses      1090
# 4     Andaman and Nicobar Islands  Kharif                      Rice     69325
# ...                           ...          ...                  ...       ...
# 1960                  West Bengal  Whole Year               Tobacco    202893
# 1961                  West Bengal  Whole Year              Turmeric    157547
# 1962                  West Bengal  Winter                    Potato    660279
# 1963                  West Bengal  Winter                      Rice  71747721
# 1964                  West Bengal  Winter                   Sesamum     14502
#
#       Production
# ...

# %%
df.to_csv("project_new.csv", index=False)
# Out:
#                        State_Name       Season                 Crop  \
# 0     Andaman and Nicobar Islands  Autumn                      Rice
# 1     Andaman and Nicobar Islands  Autumn                 Sugarcane
# 2     Andaman and Nicobar Islands  Kharif                  Arecanut
# 3     Andaman and Nicobar Islands  Kharif       Other Kharif pulses
# 4     Andaman and Nicobar Islands  Kharif                      Rice
# ...                           ...          ...                  ...
# 1960                  West Bengal  Whole Year               Tobacco
# 1961                  West Bengal  Whole Year              Turmeric
# 1962                  West Bengal  Winter                    Potato
# 1963                  West Bengal  Winter                      Rice
# 1964                  West Bengal  Winter                   Sesamum
#
#              Area    Production
# 0         8390.00  2.391600e+04
# 1          154.23  1.332950e+03
# 2         8708.00  1.450000e+04
# ...

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df['Production'].isnull().sum()
# Out:
# 3730

# %%
df['Production'].fillna(df['Production'].mean(), inplace=True)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['Production'].fillna(df['Production'].median(), inplace=True)

# %%
df[['Season', 'Area', 'Production']].head()
# Out:
#         Season    Area  Production
# 0  Kharif       1254.0      2000.0
# 1  Kharif          2.0         1.0
# 2  Kharif        102.0       321.0
# 3  Whole Year    176.0       641.0
# 4  Whole Year    720.0       165.0

# %%
df.to_csv('Crop_production1.csv', index=False)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df.shape
# Out:
# (246091, 7)

# %%
df['Production'].fillna(df['Production'].mode()[0], inplace=True)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df['Production']
# Out:
# 0           2000.0
# 1              1.0
# 2            321.0
# 3            641.0
# 4            165.0
#             ...
# 246086       801.0
# 246087       463.0
# 246088     16250.0
# 246089    597899.0
# 246090        88.0
# Name: Production, Length: 246091, dtype: float64

# %%
df.to_csv('Crop_production2.csv', index=False)

# %%
df.fillna({'Production': df['Production'].mean(), '': 0}, inplace=True)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
numeric_df = df.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr()
print("Correlation matrix of the numeric columns:")
print(correlation_matrix)
# Out:
# Correlation matrix of the numeric columns:
#             Crop_Year      Area  Production
# Crop_Year    1.000000 -0.026022    0.006989
# Area        -0.026022  1.000000    0.040587
# Production   0.006989  0.040587    1.000000

# %%
df.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
df['Year_Group'] = (df['Crop_Year'] // 5) * 5
# Aggregate production for each 5-year group
df = df.groupby('Year_Group')['Production'].sum()
df
# Out:
# Year_Group
# 1995    1.331218e+10
# 2000    3.913613e+10
# 2005    3.989017e+10
# 2010    5.100286e+10
# 2015    7.517568e+06
# Name: Production, dtype: float64

# %%
import pandas as pd

# Assuming the dataset is loaded as a DataFrame
df = pd.read_csv('Crop_production1.csv')  # Update 'your_file.csv' with the correct file name

# Verify the type of df
if isinstance(df, pd.DataFrame):
    print("The dataset is a DataFrame.")
else:
    print(f"Unexpected data type: {type(df)}. Ensure df is a DataFrame.")
# Out:
# The dataset is a DataFrame.

# %%
df = pd.read_csv('Crop_production1.csv')

# Fixing the issue
if isinstance(df, pd.Series):
    print("A single column was loaded; reloading the full dataset.")
    df = pd.read_csv('your_file.csv')  # Reload the dataset

# %%
if 'Crop_Year' not in df.columns:
    print("The 'Crop_Year' column is missing or named differently. Please verify column names.")

df['Year_Range'] = pd.cut(
    df['Crop_Year'], 
    bins=range(df['Crop_Year'].min(), df['Crop_Year'].max() + 6, 5),
    right=False,
    labels=[f"{start}-{start+4}" for start in range(df['Crop_Year'].min(), df['Crop_Year'].max() + 1, 5)]
)

# Filter out rows where Production is 0
filtered_df = df[df['Production'] != 0]

# Group the filtered data and aggregate Area and Production
aggregated_data = filtered_df.groupby(
    ['Year_Range', 'Crop'], 
    observed=False
).agg({'Area': 'sum', 'Production': 'sum'}).reset_index()

# Display the aggregated data
print(aggregated_data)



df
# Out:
# The 'Crop_Year' column is missing or named differently. Please verify column names.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Crop_Year'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Area'] = df['Area'].apply(math.ceil)
df['Production'] = df['Production'].apply(math.ceil)
df
# Out:
#     Year_Range                 Crop      Area  Production
# 0    1997-2001                Apple         0           0
# 1    1997-2001  Arcanut (Processed)         0           0
# 2    1997-2001             Arecanut   1328411     2577496
# 3    1997-2001            Arhar/Tur  16412212    21735891
# 4    1997-2001            Ash Gourd         0           0
# ..         ...                  ...       ...         ...
# 491  2012-2016                Wheat  67977549   205753885
# 492  2012-2016                  Yam         0           0
# 493  2012-2016         other fibres         0           0
# 494  2012-2016   other misc. pulses         0           0
# 495  2012-2016       other oilseeds    176616     3292766
#
# [496 rows x 4 columns]

# %%
# Filter out rows where Production is 0
filtered_df = df[df['Production'] != 0]

# Group the filtered data and aggregate Area and Production
aggregated_data = filtered_df.groupby(
    ['Year_Range', 'Crop'], 
    observed=False
).agg({'Area': 'sum', 'Production': 'sum'}).reset_index()

# Display the aggregated data
print(aggregated_data)
# Out:
#     Year_Range                 Crop      Area  Production
# 0    1997-2001  Arcanut (Processed)         0           0
# 1    1997-2001             Arecanut   1328411     2577496
# 2    1997-2001            Arhar/Tur  16412212    21735891
# 3    1997-2001        Atcanut (Raw)         0           0
# 4    1997-2001                Bajra  47176261    39137459
# ..         ...                  ...       ...         ...
# 419  2012-2016                 Urad   6734013     6763242
# 420  2012-2016               Varagu         0           0
# 421  2012-2016                Wheat  67977549   205753885
# 422  2012-2016   other misc. pulses         0           0
# 423  2012-2016       other oilseeds    176616     3292766
#
# [424 rows x 4 columns]

# %%
# Filter out rows where Production is 0
filtered_df = df[df['Production'] != 0]

# Group the filtered data and aggregate Area and Production
aggregated_data = filtered_df.groupby(
    ['Season', 'Crop'], 
    observed=False
).agg({'Area': 'sum', 'Production': 'sum'}).reset_index()

# Filter for Kharif and Arecanut with specific values
result = aggregated_data[
    (aggregated_data['Season'] == 'Kharif') & 
    (aggregated_data['Crop'] == 'Arecanut') & 
    (aggregated_data['Area'] == 1254.0) & 
    (aggregated_data['Production'] == 2000.0)
]

# Display the result
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 5
#       2 filtered_df = df[df['Production'] != 0]
#       4 # Group the filtered data and aggregate Area and Production
# ----> 5 aggregated_data = filtered_df.groupby(
#       6     ['Season', 'Crop'],
#       7     observed=False
#       8 ).agg({'Area': 'sum', 'Production': 'sum'}).reset_index()
#      10 # Filter for Kharif and Arecanut with specific values
#      11 result = aggregated_data[
#      12     (aggregated_data['Season'] == 'Kharif') &
#      13     (aggregated_data['Crop'] == 'Arecanut') &
#      14     (aggregated_data['Area'] == 1254.0) &
#      15     (aggregated_data['Production'] == 2000.0)
#      16 ]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9156, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
# ...
