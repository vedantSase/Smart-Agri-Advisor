# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\SOMESH\Desktop\JN\Project\Datasets\Crop_recommendation.csv')

# %%
df2=pd.read_csv(r'C:\Users\SOMESH\Desktop\JN\Project\Datasets\annual-enterprise-survey-2023-financial-year-provisional.csv')

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df2
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df.notnull().sum().sum()
# Out:
# 17600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df['N'].sum().sum()
# Out:
# 111214

# %%
for i in df['N']:
    i+=df['N']
    print(i)
# Out:
# 0       180
# 1       175
# 2       150
# 3       164
# 4       168
#        ...
# 2195    197
# 2196    189
# 2197    208
# 2198    207
# 2199    194
# Name: N, Length: 2200, dtype: int64
# 0       175
# 1       170
# 2       145
# 3       159
# 4       163
#        ...
# 2195    192
# 2196    184
# 2197    203
# 2198    202
# 2199    189
# Name: N, Length: 2200, dtype: int64
# 0       150
# 1       145
# 2       120
# 3       134
# 4       138
#        ...
# 2195    167
# 2196    159
# 2197    178
# 2198    177
# 2199    164
# Name: N, Length: 2200, dtype: int64
# 0       164
# 1       159
# 2       134
# 3       148
# 4       152
#        ...
# 2195    181
# 2196    173
# 2197    192
# 2198    191
# 2199    178
# Name: N, Length: 2200, dtype: int64
# 0       168
# 1       163
# 2       138
# 3       152
# 4       156
#        ...
# 2195    185
# 2196    177
# 2197    196
# 2198    195
# 2199    182
# Name: N, Length: 2200, dtype: int64
# 0       159
# 1       154
# 2       129
# ...

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2200, step=1)

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
df.columns.values
# Out:
# array(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall',
#        'label'], dtype=object)

# %%
df.describe(include='all')
# Out:
#                   N            P            K  temperature     humidity  \
# count   2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      50.551818    53.362727    48.149091    25.616244    71.481779
# std       36.917334    32.985883    50.647931     5.063749    22.263812
# min        0.000000     5.000000     5.000000     8.825675    14.258040
# 25%       21.000000    28.000000    20.000000    22.769375    60.261953
# 50%       37.000000    51.000000    32.000000    25.598693    80.473146
# 75%       84.250000    68.000000    49.000000    28.561654    89.948771
# max      140.000000   145.000000   205.000000    43.675493    99.981876
#
#                  ph     rainfall label
# count   2200.000000  2200.000000  2200
# ...

# %%
df['temperature']
# Out:
# 0       20.879744
# 1       21.770462
# 2       23.004459
# 3       26.491096
# 4       20.130175
#           ...
# 2195    26.774637
# 2196    27.417112
# 2197    24.131797
# 2198    26.272418
# 2199    23.603016
# Name: temperature, Length: 2200, dtype: float64

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.sort_values(by="humidity")
# Out:
#        N   P   K  temperature   humidity        ph    rainfall     label
# 230   28  76  82    20.566019  14.258040  6.654425   83.759371  chickpea
# 245   35  64  78    17.928459  14.273280  7.496645   85.373788  chickpea
# 270   42  74  83    19.258256  14.280419  7.545258   65.780420  chickpea
# 219   31  70  77    20.888187  14.323138  6.492546   90.462283  chickpea
# 296   48  65  78    17.437327  14.338474  7.861128   73.092670  chickpea
# ...   ..  ..  ..          ...        ...       ...         ...       ...
# 1814  19  15  34    26.296449  99.658092  5.685889  215.919505   coconut
# 1891  21  20  31    25.600337  99.724010  5.855458  165.824873   coconut
# 1892   3   9  35    26.916419  99.846716  6.318553  225.632366   coconut
# 1864   6  13  29    27.311557  99.969060  5.832608  201.825863   coconut
# 1889  40  22  29    27.558218  99.981876  5.735364  174.625648   coconut
#
# [2200 rows x 8 columns]

# %%
df.iloc[5]
# Out:
# N                     69
# P                     37
# K                     42
# temperature    23.058049
# humidity       83.370118
# ph              7.073454
# rainfall         251.055
# label               rice
# Name: 5, dtype: object

# %%
df[0:3]
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice

# %%
df.loc[:, ["temperature","humidity"]]
# Out:
#       temperature   humidity
# 0       20.879744  82.002744
# 1       21.770462  80.319644
# 2       23.004459  82.320763
# 3       26.491096  80.158363
# 4       20.130175  81.604873
# ...           ...        ...
# 2195    26.774637  66.413269
# 2196    27.417112  56.636362
# 2197    24.131797  67.225123
# 2198    26.272418  52.127394
# 2199    23.603016  60.396475
#
# [2200 rows x 2 columns]

# %%
df.iloc[:10, :]
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
df.iloc[:, :10]
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.iloc[:5, :5]
# Out:
#     N   P   K  temperature   humidity
# 0  90  42  43    20.879744  82.002744
# 1  85  58  41    21.770462  80.319644
# 2  60  55  44    23.004459  82.320763
# 3  74  35  40    26.491096  80.158363
# 4  78  42  42    20.130175  81.604873

# %%
df.iloc[3:5, 0:2]
# Out:
#     N   P
# 3  74  35
# 4  78  42

# %%
df.iloc[[1,2,4], [0, 2]]
# Out:
#     N   K
# 1  85  41
# 2  60  44
# 4  78  42

# %%
df.iloc[1:3, :]
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice

# %%
df['temperature'].iloc[6]
# Out:
# 22.70883798

# %%
df2
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
merged_df = df.merge(df2, left_on='N', right_on='Year')
merged_df.to_csv('joined_file.csv', index=False)

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [N, P, K, temperature, humidity, ph, rainfall, label, Year, Industry_aggregation_NZSIOC, Industry_code_NZSIOC, Industry_name_NZSIOC, Units, Variable_code, Variable_name, Variable_category, Value, Industry_code_ANZSIC06]
# Index: []
